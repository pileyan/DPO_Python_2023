# %% [markdown]
# # **Работа с файлами**

# %% [markdown]
# ## Типы файлов

# %% [markdown]
# + структурированные (табличные): csv, txt, xsl и т.д.
# + неструктурированные (текст): doc, txt и т.д.

# %% [markdown]
# ## Поиск пути к файлу

# %% [markdown]
# Функция `getcwd()` из модуля `os` возвращает нам путь к ваше рабочей папке. Так, например, в Windows по умолчанию Anaconda делает рабочей папкой для Jupyter папку пользователя в Users. Это можно изменить или глобально, прописав путь к вашей папке в свойствах, или локально в рамках сессии.

# %%
import os #библиотека которая занимается навигацией по компьютеру
os.getcwd()
# Out:
# '/Users/tatiana/Desktop/Files_11.03'

# %% [markdown]
# Метод `.listdir()` вернет нам список содержимого директории. Очень полезная функция - можно запустить цикл, если нужно обработать все файлы в папке.

# %%
os.listdir('')
# Out:
# ['task1.txt',
#  '.DS_Store',
#  'task3.tsv',
#  'task2.csv',
#  'files.ipynb',
#  'example.txt',
#  '.ipynb_checkpoints']

# %%
[i for i in os.listdir(os.getcwd()) if '.txt' in i]
# Out:
# ['task1.txt', 'example.txt']

# %%
list(os.walk('/Users/tatiana/Desktop/'))
# Out:
# [('/Users/tatiana/Desktop/',
#   ['Yaroslavl',
#    'bus_dubl_y',
#    'Статистика',
#    'electrocars',
#    'Files_11.03',
#    't2',
#    'MT_UoL_205_Surname',
#    '.ipynb_checkpoints',
#    'MT_UoL_206_Surname',
#    'Безбилетнки'],
#   ['4:5 разделы.docx',
#    'Книга19.xlsx',
#    'круизы.xlsx',
#    'busline.xlsx',
#    'Снимок экрана 2023-02-14 в 20.44.17.png',
#    'Журнал 2019 (Владивосток).xlsx',
#    '~$E_Транспорт_блок_v1.2.pptx',
#    'Снимок экрана 2023-02-28 в 19.39.47.png',
#    'ptline.xlsx',
#    'Камчатка_27-04-2022_19-48-30.csv',
#    'Снимок экрана 2023-02-13 в 22.13.46.png',
#    'оценка удобства пересадки.pptx',
#    'Снимок экрана 2023-02-10 в 21.00.50.png',
#    'Снимок экрана 2023-03-02 в 22.51.10.png',
#    'Снимок экрана 2023-03-04 в 20.47.30.png',
#    'Снимок экрана 2023-02-11 в 14.37.28.png',
#    'Протокол комиссии_Шарипова С.С._Анализ данных (1).xlsx',
#    'Снимок экрана 2023-03-07 в 19.57.08.png',
#    'time_v2.xls',
#    'Fj79zRSXEAAL4Mn.jpeg',
#    'g1.xlsx',
#    'Снимок экрана 2023-02-18 в 00.20.26.png',
#    's7_1.png',
#    's3_while.ipynb',
#    'answer_t1.xlsx',
#    'l3.pdf',
#    'matrix_before.csv',
#    '.DS_Store',
#    '~$sep_v2.xlsx',
#    'Снимок экрана 2023-02-15 в 17.31.32.png',
#    'ВЮР211 Основы программирования на Python Перевышина Т.О. 9.12.2022.pdf',
#    'aopa-points-export.xlsx',
#    's7_2.png',
#    'Снимок экрана 2023-02-24 в 15.59.13.png',
#    'l2_tp_wwd.pdf',
#    'progressivnaya-matematika-v2.5932.xxl.webp',
#    'расписание.xlsx',
#    'base.xlsx',
#    'Снимок экрана 2023-02-13 в 20.44.04.png',
#    'туристы.xlsx',
#    '.localized',
#    'Снимок экрана 2023-02-16 в 16.14.59.png',
#    'sep_v2.xlsx',
#    '~$s3_spb.pptx',
#    'Перевышина. Комиссия.pptx',
#    'туристы ЮФО.xlsx',
#    'Снимок экрана 2023-02-12 в 19.04.26.png',
#    'Реестр_v1 - Лист15.csv',
#    'Перевышина Резюме.docx',
#    'Снимок экрана 2023-02-14 в 14.18.26.png',
#    'kisspng-human-behavior-technology-line-clip-art-5af6c69043d1a8.6143757715261221282778.jpg',
#    '1_10.png',
#    'Снимок экрана 2023-02-23 в 16.36.41.png',
#    '~$туристы.xlsx',
#    'Снимок экрана 2023-02-14 в 20.47.33.png',
#    'Снимок экрана 2023-02-16 в 19.09.05.png',
#    'time.xlsx',
#    'f1.png',
#    'qq.xlsx',
#    'tram_hour.xlsx',
#    'main_info_DA6.pptx',
#    'Снимок экрана 2023-03-03 в 19.10.27.png',
#    'предложения.xlsx',
#    '~$Книга19.xlsx',
#    '3_Распределение населения по возрастным группам(1).pdf',
#    'Task list.xlsx',
#    'Снимок экрана 2023-02-12 в 19.08.37.png',
#    'Снимок экрана 2023-02-25 в 23.43.19.png',
#    'Снимок экрана 2023-02-23 в 17.13.59.png',
#    'Презентация22.pptx',
#    'Лекция 1.pptx',
#    'aero_matrix.xlsx',
#    's1.pdf',
#    'Снимок экрана 2023-03-02 в 22.55.12.png',
#    'rl (2).PDF.pdf',
#    'Книга1_1.xlsx',
#    'Снимок экрана 2023-03-03 в 18.46.26.png',
#    'Снимок экрана 2023-02-10 в 20.58.25.png',
#    'Снимок экрана 2023-03-02 в 22.57.26.png',
#    'main_info_DA6.pdf',
#    'Презентация1.pptx',
#    '3_1.png',
#    'Снимок экрана 2023-02-14 в 22.26.56.png',
#    'Камчатка_28-04-2022_15-15-48.csv',
#    'Демин_Протокол_комиссии_Программирование_на_языке_Python.xlsx',
#    'aerodrom.xlsx',
#    'Снимок экрана 2023-02-28 в 19.39.05.png',
#    '~$Темы Дептранс+правки.pptx',
#    'Презентация1 [Автосохраненный].pptx',
#    'че.pptx',
#    'Снимок экрана 2023-02-12 в 18.16.59.png',
#    'cf93af9f-6c3c-4c59-a846-dd20dad7dadd.pdf',
#    'оплата июнь.xlsx',
#    '3_0.png',
#    'Книга1.xlsx',
#    'Снимок экрана 2023-02-28 в 19.38.44.png',
#    'Снимок экрана 2023-02-23 в 18.06.37.png',
#    'Книга31.xlsx',
#    'l1.des_dis_nd.pdf',
#    '3_2.png',
#    'Протокол комиссии_Суханкулов С._Анализ данных.pdf',
#    'Снимок экрана 2023-02-20 в 19.11.06.png',
#    'Протокол комиссии_Шарипова С.С._Анализ данных (1).pdf',
#    '1_1.png',
#    'megaGymDataset.xlsx',
#    'Снимок экрана 2023-02-15 в 17.32.30.png',
#    'Снимок экрана 2023-03-03 в 00.07.18.png',
#    'time_v3.xlsx',
#    'time_v2.xlsx',
#    'avto_msc.xlsx',
#    'Презентация_Транспорт_v3.pdf',
#    'Снимок экрана 2023-02-16 в 19.07.25.png',
#    'Снимок экрана 2023-02-10 в 21.00.00.png',
#    '~$.word_clean.docx',
#    'подтверждение заказа Справки об отсутсвии судимости .pdf',
#    'answer_t1_3_3.xlsx',
#    'E_Транспорт_блок_v1.2.pdf',
#    'Презентация1 [Нередактируемый].pptx',
#    'Снимок экрана 2023-03-03 в 00.12.16.png',
#    'Снимок экрана 2023-02-15 в 01.56.54.png',
#    'Снимок экрана 2023-02-26 в 23.45.06.png',
#    'Снимок экрана 2023-02-18 в 15.06.29.png',
#    'time_v2.csv',
#    '2_2.png',
#    'Снимок экрана 2023-02-15 в 17.30.54.png',
#    'Оценка качества пересадки.docx',
#    'l1.des_dis_nd.pptx',
#    'TRANSACTIONS_EXT_question.xlsx',
#    '2_3.png',
#    'Презентация_Транспорт_v3.pptx',
#    'загруженное.png',
#    'Лекция 1.Вводная.pptx',
#    '2_1.png',
#    'Снимок экрана 2023-02-13 в 22.15.38.png',
#    'saha_point_profitravel.csv',
#    'ВЮР211 Основы программирования на Python Перевышина Т.О. 27.01.2023.pdf',
#    '~$расписание.xlsx',
#    'Условие эффективности дисперсиz оценки.docx',
#    'Снимок экрана 2023-02-18 в 20.28.11.png',
#    'Снимок экрана 2023-02-13 в 18.54.18.png',
#    'Снимок экрана 2023-02-14 в 20.45.58.png',
#    'Книга16.xlsx',
#    'расписание(АвтоматическиВосстановлено).xlsx',
#    'НЭ_2021_2021_Спецификация_ПРОГ_Начальный.pdf',
#    'pr.ipynb',
#    'Снимок экрана 2023-02-17 в 00.13.20.png',
#    'Снимок экрана 2023-02-12 в 19.42.23.png',
#    'Снимок экрана 2023-02-23 в 18.26.09.png',
#    'Снимок экрана 2023-02-20 в 18.04.37.png',
#    'Снимок экрана 2023-02-23 в 19.54.13.png',
#    '~$Презентация1 [Нередактируемый].pptx',
#    'Лекция 1.Вводная.pdf',
#    '233641048_2540522619427837_659498404940817827_n.jpeg',
#    'S3.docx',
#    '2_5.png',
#    'busline.csv',
#    'Снимок экрана 2023-02-10 в 20.58.55.png',
#    'Снимок экрана 2023-03-03 в 20.34.07.png',
#    'рассчеты.xlsx',
#    'Снимок экрана 2023-02-24 в 15.53.47.png',
#    '1.png',
#    '~$time_v3.xlsx',
#    '5 этап.pptx',
#    'Снимок экрана 2023-02-12 в 19.10.15.png',
#    'Снимок экрана 2023-03-02 в 22.51.34.png',
#    'Заявление Перевышина.docx',
#    'Снимок экрана 2023-02-11 в 14.38.49.png',
#    'chocolate_bars.csv',
#    '2_6.png',
#    '1.descrip.pptx']),
#  ('/Users/tatiana/Desktop/Yaroslavl',
#   ['maps', 'shp', 'addresses', 'registry'],
#   ['Yaroslavl.qgs', 'Yaroslavl.qgs~']),
#  ('/Users/tatiana/Desktop/Yaroslavl/maps',
#   [],
#   ['Yaroslavl_2.png',
#    'Yaroslavl_3.png',
#    'Yaroslavl_3.pdf',
#    'Yaroslavl.png',
#    'Yaroslavl.pdf']),
#  ('/Users/tatiana/Desktop/Yaroslavl/shp',
#   ['landuse', 'PARS_tables', 'data', 'PTAL'],
#   ['PT_segment_graph_simplified.dbf',
#    'city_graph_max_supply.shp',
#    'city_graph.prj',
#    'city_graph_max_supply.cpg',
#    'PT_stops.prj',
#    'osm_buildings.shx',
#    'city_data.dbf',
#    'city_data_all.dbf',
#    'city_graph_max_supply.shx',
#    'city_graph_max_supply.qmd',
#    'osm_buildings.cpg',
#    'osm_buildings.shp',
#    'GRID_300.prj',
#    'osm_waterway.dbf',
#    'admin_bound.shx',
#    'admin_bound.cpg',
#    'admin_bound.shp',
#    'GRID_100.prj',
#    'PT_stops_buffer.dbf',
#    'city_data_old.dbf',
#    'admin_bound.dbf',
#    'osm_water.prj',
#    'city_data_old.cpg',
#    'PT_stops_buffer.cpg',
#    'city_data_old.shp',
#    'PT_stops_buffer.shp',
#    'osm_waterway.shx',
#    'osm_waterway.qmd',
#    'rural_data.prj',
#    'PT_stops_buffer.shx',
#    'city_data_old.shx',
#    'osm_roads.prj',
#    'osm_waterway.shp',
#    'osm_waterway.cpg',
#    'osm_buildings.dbf',
#    'landuse_for_grid.prj',
#    'city_data_all.shp',
#    'city_data.cpg',
#    'PT_segment_graph_simplified.shx',
#    'city_data.shp',
#    'city_data_all.cpg',
#    'PT_segment_graph_simplified.qmd',
#    'PT_graph.prj',
#    'PT_segment_graph_simplified.shp',
#    'city_data_all.shx',
#    'city_data.shx',
#    'PT_segment_graph_simplified.cpg',
#    'city_graph_max_supply.dbf',
#    'city_graph.cpg',
#    'city_graph_max_supply.prj',
#    'city_graph.shp',
#    'PT_stops.shp',
#    'PT_stops.cpg',
#    'PT_graph.dbf',
#    'city_graph.shx',
#    'PT_stops.shx',
#    'osm_buildings.prj',
#    'PT_stops.qmd',
#    'landuse_for_grid.dbf',
#    'osm_roads.dbf',
#    'GRID_300.cpg',
#    'GRID_300.shp',
#    'GRID_100.shx',
#    'rural_data.dbf',
#    'GRID_300.shx',
#    'osm_water.dbf',
#    'GRID_100.cpg',
#    'GRID_100.shp',
#    'admin_bound.prj',
#    'GRID_100.dbf',
#    'osm_water.cpg',
#    'osm_water.shp',
#    'rural_data.shx',
#    'PT_stops_buffer.prj',
#    'city_data_old.prj',
#    'osm_roads.shx',
#    'osm_water.qmd',
#    'osm_water.shx',
#    'rural_data.shp',
#    'rural_data.cpg',
#    'osm_roads.shp',
#    'osm_roads.cpg',
#    'osm_waterway.prj',
#    'GRID_300.dbf',
#    'PT_graph.shx',
#    'landuse_for_grid.shp',
#    'landuse_for_grid.cpg',
#    'city_data_all.prj',
#    'city_data.prj',
#    'PT_stops.dbf',
#    'PT_graph.shp',
#    'landuse_for_grid.shx',
#    'PT_graph.cpg',
#    'PT_segment_graph_simplified.prj',
#    'city_graph.dbf']),
#  ('/Users/tatiana/Desktop/Yaroslavl/shp/landuse',
#   [],
#   ['landuse_bua.prj',
#    'temp.prj',
#    'road_main_buffer_4m.shp',
#    'road_main_buffer_4m.cpg',
#    'road_main_buffer_4m.shx',
#    'road_main_buffer_4m.qmd',
#    'landuse.shx',
#    'landuse.qmd',
#    'landuse.shp',
#    'landuse.cpg',
#    'landuse_bua_roads.dbf',
#    'landuse_bua_roads.shp',
#    'landuse.dbf',
#    'landuse_bua_roads.cpg',
#    'landuse_bua_roads.shx',
#    'landuse_bua_roads.qmd',
),
#  ('/Users/tatiana/Desktop/Yaroslavl/shp/data',
#   [],
#   ['graph_buffer_20m.cpg',
#    'graph_buffer_20m.shp',
#    'graph_buffer_20m.shx',
#    'landuse.shx',
#    'skeleton_busrow.prj',
#    'graph_busrow_simplified.shx',
#    'landuse.shp',
#    'landuse.cpg',
#    'graph_busrow_simplified.cpg',
#    'graph_busrow_simplified.shp',
#    'graph_tram_simplified.prj',
#    'landuse.dbf',
#    'graph_busrow_simplified.dbf',
#    'skeleton_tramrow.prj',
#    'graph_buffer_20m.dbf',
#    'skeleton1.prj',
#    'PT_segment_graph_simplified_bus.prj',
#    'skeleton1.dbf',
#    'PT_segment_graph_simplified_bus.dbf',
#    'graph_buffer_20m.prj',
#    'route_count.xlsx',
#    'skeleton_tramrow.dbf',
#    'skeleton_busrow.cpg',
#    'skeleton_busrow.shp',
#    'graph_tram_simplified.shx',
#    'tramrow.xlsx',
#    'busrow.xlsx',
#    'landuse.prj',
#    'graph_busrow_simplified.prj',
#    'skeleton_busrow.shx',
#    'graph_tram_simplified.shp',
#    'graph_tram_simplified.cpg',
#    'graph_tram_simplified.dbf',
#    '222_Yaroslavl_border_9.gpkg',
#    '222_Yaroslavl_team_1.gpkg',
#    'skeleton_busrow.dbf',
#    'skeleton_tramrow.shp',
#    'skeleton1.shx',
#    'skeleton_tramrow.cpg',
#    'PT_segment_graph_simplified_bus.shx',
#    'skeleton1.shp',
#    'skeleton_tramrow.shx',
#    'skeleton1.cpg',
#    'PT_segment_graph_simplified_bus.shp',
#    'PT_segment_graph_simplified_bus.cpg']),
#  ('/Users/tatiana/Desktop/Yaroslavl/shp/PTAL',
#   [],
#   ['PTAL_grid_100m_clipped_bua_roads.cpg',
#    'PTAL_grid_100m_clipped_bua_roads.shp',
#    'area_bua_roads.qmd',
#    'PTAL_grid_100m_centroids.prj',
#    'OD_matrix_threads.xlsx',
#    'area_bua.xlsx',
#    'PTAL_grid_100m_clipped_bua_roads.qmd',
#    'PTAL_grid_100m_clipped_bua_roads.shx',
#    'PTAL_grid_100m_clipped_bua.prj',
#    'area_clipped_city.qmd',
#    'nextgis_roads.prj',
#    'Yaroslavl_PTAL_area.xlsx',
# ...
#    '211 будни ( апрель ).xlsx',
#    'Е70 будни (апрель-май).xlsx',
#    '821 выходные.xlsx',
#    '237 выходные.xlsx',
#    '620 будни.xlsx',
#    '74 выходные.xlsx',
#    'Т32 будни.xlsx',
#    'ВЧ выходные.xlsx',
#    '664 будни (апрель).xlsx',
#    '821 будни (март-апрель).xlsx',
#    'Т30 выходные.xlsx',
#    'О32 будни (март).xlsx',
#    '46 будни.xlsx',
#    '725 выходные.xlsx',
#    'Т27 выходные.xlsx',
#    '237 будни ( апрель-май ).xlsx',
#    '557 выходные.xlsx',
#    'Т41 будни.xlsx',
#    '725 будни.xlsx',
#    '131 будни.xlsx',
#    'О24 выходные.xlsx',
#    '776 будни (март).xlsx',
#    'Т24 выходные.xlsx',
#    '14 выходные.xlsx',
#    '74 будни.xlsx',
#    '59 будни ( апрель ).xlsx',
#    '21 будни.xlsx',
#    '230 суббота.xlsx',
#    '735 выходные.xlsx',
#    '569 выходные.xlsx',
#    '841 выходные.xlsx',
#    '97 будни.xlsx',
#    '257 выходные.xlsx',
#    '279 выходные.xlsx',
#    '775 будни.xlsx',
#    '230 будни ( апрель-май ).xlsx',
#    '625 будни ( апрель ).xlsx',
#    '893 будни (апрель-май).xlsx',
#    '79 будни.xlsx',
#    '86 будни.xlsx',
#    '776 будни (апрель-май).xlsx',
#    'М6 будни.xlsx',
#    '615 выходные.xlsx',
#    'Т55 будни.xlsx',
#    '59 выходные.xlsx',
#    '209 выходные.xlsx',
#    '569 будни.xlsx',
#    '230 воскресенье.xlsx',
#    '859 будни.xlsx',
#    '849 будни (март-апрель).xlsx',
#    '34К будни ( апрель ).xlsx',
#    '86 выходные.xlsx',
#    '230 будни ( март ).xlsx',
#    'Т32 выходные.xlsx',
#    '730 выходные.xlsx',
#    '872 будни.xlsx',
#    '34К будни ( май ).xlsx',
#    '51 будни.xlsx',
#    '14 будни ( март ).xlsx',
#    'Т55 выходные.xlsx',
#    '36 будни.xlsx',
#    'О24 будни (май).xlsx',
#    '885 будни.xlsx',
#    '664 будни (май).xlsx',
#    '625 будни ( март ).xlsx',
#    'Т41 выходные.xlsx',
#    '177 выходные.xlsx',
#    '662 будни (март).xlsx',
#    'О32 выходные.xlsx',
#    '242 выходные.xlsx',
#    '209 будни ( май ).xlsx',
#    'Т22 выходные.xlsx',
#    'Е70 выходные.xlsx',
#    '59 будни ( март ).xlsx',
#    '237 будни ( март ).xlsx',
#    '211 будни ( май ).xlsx',
#    '247 будни.xlsx',
#    '664 будни (март).xlsx',
#    '20 будни.xlsx',
#    'ВЧ будни (май).xlsx',
#    'Т27 будни.xlsx',
#    '805 суббота.xlsx',
#    '21 выходные.xlsx',
#    '36 выходные.xlsx',
#    'О24 будни (март).xlsx',
#    '849 выходные.xlsx',
#    '620 выходные.xlsx',
#    '627 вторник-четверг.xlsx',
#    '730 будни.xlsx',
#    'Т63 будни.xlsx',
#    '51 выходные.xlsx',
#    '893 выходные.xlsx',
#    '849 будни (май).xlsx',
#    'М6 выходные.xlsx',
#    '68 выходные.xlsx',
#    '662 будни (апрель-май).xlsx',
#    '735 будни.xlsx',
#    '211 выходные.xlsx',
#    '143 будни.xlsx',
#    '133 выходные.xlsx',
#    '34 будни.xlsx',
#    '52 выходные.xlsx',
#    '254 будни.xlsx',
#    '627 выходные.xlsx',
#    '759 выходные.xlsx',
#    'Т51 будни.xlsx',
#    '197 будни.xlsx',
#    'Е70 будни (март).xlsx',
#    'Т22 будни.xlsx',
#    '792 будни.xlsx',
#    'О24 будни (апрель).xlsx',
#    'Т77 будни.xlsx',
#    '143 выходные.xlsx',
#    'ВЧ будни (апрель).xlsx',
#    '52 будни ( март ).xlsx']),
#  ('/Users/tatiana/Desktop/Безбилетнки/Пассажиропоток/17 авт. парк',
#   [],
#   ['С908 будни.xls',
#    '288 выходные (март).xls',
#    '108 выходные.xls',
#    '948 выходные.xls',
#    'М97 будни.xls',
#    '108 будни.xls',
#    'Е91 будни.xls',
#    '18 выходные.xls',
#    'Н13 будни.xls',
#    '948 будни.xls',
#    '737 будни.xls',
#    '860 будни.xls',
#    '898к выходные.xls',
#    '94 будни.xls',
#    '938 выходные.xls',
#    '980 выходные.xls',
#    '288 будни (апр-май).xls',
#    '852 будни.xls',
#    '802 выходные.xls',
#    '921 будни.xls',
#    'С53 выходные.xls',
#    'С163 будни.xls',
#    'М87 выходные.xls',
#    '146 будни.xls',
#    'М95 выходные.xls',
#    '293 выходные.xls',
#    'М96 будни.xls',
#    '938 будни.xls',
#    '18 будни.xls',
#    'М89 будни.xls',
#    '933 выходные.xls',
#    'Е80 выходные.xls',
#    '933 будни.xls',
#    '980 будни.xls',
#    '921 выходные.xls',
#    'С163 выходные.xls',
#    'ДП98 будни.xls',
#    '802 будни.xls',
#    '860 выходные.xls',
#    '813 выходные.xls',
#    '737 выходные.xls',
#    '898 будни.xls',
#    'М95 будни.xls',
#    '947 выходные.xls',
#    'Н8 выходные.xls',
#    '813 будни.xls',
#    'М96 выходные.xls',
#    'С53 будни.xls',
#    'Е91 выходные.xls',
#    '852 выходные.xls',
#    '146 выходные.xls',
#    '947 будни.xls',
#    'М87 будни.xls',
#    'М97 выходные.xls',
#    'Е80 будни.xls',
#    '288 выходные (апр-май).xls',
#    '94 выходные.xls',
#    '293 будни.xls',
#    'Н8 будни.xls',
#    '691 будни.xls',
#    '691 выходные.xls',
#    'М89 выходные.xls',
#    'С908 выходные.xls',
#    '629 будни.xls',
#    '629 выходные.xls',
#    '288 будни (март).xls',
#    'Н13 выходные.xls',
#    'С809 выходные.xls',
#    '213 будни.xls',
#    '898к будни.xls',
#    'С809 будни.xls',
#    '213 выходные.xls']),
#  ('/Users/tatiana/Desktop/Безбилетнки/Пассажиропоток/Южный (9,13,16)',
#   [],
#   ['736 будни.xlsx',
#    '292 будни.xlsx',
#    '112Э будни.xlsx',
#    '858 выходные.xlsx',
#    '30 выходные.xlsx',
#    '814 будни.xlsx',
#    '858 будни.xlsx',
#    '655 выходные.xlsx',
#    '844 будни.xlsx',
#    '826 будни.xlsx',
#    '646 выходные.xlsx',
#    '766 будни.xlsx',
#    '704 будни.xlsx',
#    '54 выходные.xlsx',
#    '703 будни.xlsx',
#    '913 будни.xlsx',
#    'МЦ1 выхдные.xlsx',
#    '35 будни.xlsx',
#    '897 будни.xlsx',
#    '736 выходные.xlsx',
#    'Е85 будни (март-апрель).xlsx',
#    '824 будни.xlsx',
#    '234 выходные.xlsx',
#    '30 будни.xlsx',
#    '826 выходные.xlsx',
#    'МЦ1 будни.xlsx',
#    '655 будни.xlsx',
#    '844 выходные.xlsx',
#    '899 будни.xlsx',
#    '749 будни.xlsx',
#    '54 будни.xlsx',
#    '234 будни.xlsx',
#    '824 выходные.xlsx',
#    '899 выходные.xlsx',
#    '762 будни.xlsx',
#    '228 будни.xlsx',
#    '818 будни.xlsx',
#    '913 выходные.xlsx',
#    '655К будни.xlsx',
#    '657 будни.xlsx',
#    '646 будни.xlsx',
#    '897 выходные.xlsx',
#    '749 выходные.xlsx',
#    '655К выходные.xlsx',
#    'Е29 будни.xlsx',
#    '228 выходные.xlsx',
#    '814 выходные.xlsx',
#    '864 будни.xlsx',
#    '112Э выходные.xlsx',
#    '703 выходные.xlsx',
#    '864 выходные.xlsx',
#    '35 выходные.xlsx',
#    '657 выходные.xlsx']),
#  ('/Users/tatiana/Desktop/Безбилетнки/Пассажиропоток/Электробусы',
#   [],
#   ['Э_791-будни(апрель-май) кольцевой.xlsx',
#    'Э_393-будни(весна).xlsx',
#    'Э_778-будни(май).xlsx',
#    'Э_Т36-будни(весна).xlsx',
#    'Э_778-будни(апрель).xlsx',
#    'Э_С511-выходные(апрель-май).xlsx',
#    '622 выходные.xlsx',
#    '622 будни.xlsx',
#    'Э_М53-выходные(весна).xlsx',
#    'Э_С511-будни(апрель-май).xlsx',
#    'Э_С920-выходные(весна).xlsx',
#    'Э_Т61-будни(весна).xlsx',
#    'Э_с510-будни(апрель).xlsx',
#    'Э_Т73-будни(апрель).xlsx',
#    'Э_С538-будни(апрель-май).xlsx',
#    'Э_Sk1-выходные(март) АСКП-308, по факту -1001.xlsx',
#    'Э_803-выходные(май).xlsx',
#    'Э_93-будни(весна).xlsx',
#    'Э_С538-будни(март).xlsx',
#    'Э_Т36-выходные(весна).xlsx',
#    'Э_С511-выходные(март).xlsx',
#    'Э_С920-будни(март).xlsx',
#    'Э_791-выходные(март).xlsx',
#    'Э_791-будни(март).xlsx',
#    'Э_Н3-будни(декабрь-май).xlsx',
#    'Э_510-выходные(весна).xlsx',
#    'Э_М16-выходные(весна).xlsx',
#    'Э_803-будни(март-апрель).xlsx',
#    'Э_Т18-выходные(весна).xlsx',
#    'Э_Т61-выходные(весна).xlsx',
#    'Э_Н3-выходные(декабрь-май).xlsx',
#    'Э_С538-выходные(весна).xlsx',
#    'Э_Т83-будни(весна).xlsx',
#    'Э_Т80-выходные(весна).xlsx',
#    'Э_Т73-выходные(весна).xlsx',
#    'Э_154-выходные(весна).xlsx',
#    'Э_778-будни(март).xlsx',
#    'Э_Т80-будни(апрель).xlsx',
#    'Э_Т56-будни(весна).xlsx',
#    'Э_Т18-будни(весна).xlsx',
#    'Э_М53-будни(весна).xlsx',
#    'Э_Т42-выходные(весна).xlsx',
#    'Э_Sk1-будни(апрель) АСКП 1098, по факту-3936.xlsx',
#    'Э_Sk1-будни(май) АСКП -1086, по факту-2813.xlsx',
#    'Э_649-выходные(весна) 1 день.xlsx',
#    'Э_803-будни(май).xlsx',
#    'Э_Т34-будни(декабрь-март).xlsx',
#    'Э_Т21-выходные(февраль-март).xlsx',
#    'Э_Т83-выходные(весна).xlsx',
#    'Э_С920-будни(апрель-май).xlsx',
#    'Э_Т73-будни(май).xlsx',
#    'Э_Т76-будни(весна).xlsx',
#    'Э_Т80-будни(март).xlsx',
#    'Э_Sk1-будни(март) АСКП-886,по факту-3589.xlsx',
#    'Э_791-выходные(апрель) кольцевой.xlsx',
#    'Э_Т42-будни(весна).xlsx',
#    'Э_154-будни(весна).xlsx',
#    'Э_733-будни(весна).xlsx',
#    'Э_Т34-выходные(декабрь-март).xlsx',
#    'Э_649-будни(весна).xlsx',
#    'Э_С510-будни(март).xlsx',
#    'Э_М16-будни(весна).xlsx',
#    'Э_393-выходные(весна).xlsx',
#    'Э_Sk1-выходные(май) АСКП-351, по факту-846.xlsx',
#    'Э_Т80-будни(май).xlsx',
#    'Э_778-выходные(весна).xlsx',
#    'Э_Т21-будни(февраль-март).xlsx',
#    'Э_832-выходные(весна).xlsx',
#    'Э_803-выходные(март-апрель).xlsx',
#    'Э_93-выходные(весна).xlsx',
#    'Э_733-выходные(весна).xlsx',
#    'Э_Sk1-выходные (апрель) АСКП-388, по факту-1181.xlsx',
#    '53 будни.xlsx',
#    'Э_Т73-будни(март).xlsx',
#    'Э_С511-будни(март).xlsx',
#    'Э_832-будни(весна).xlsx']),
#  ('/Users/tatiana/Desktop/Безбилетнки/Пассажиропоток/Северо-Восточный (3,6,7)',
#   [],
#   ['136 выходные.xlsx',
#    '867 будни.xlsx',
#    '40 выходные.xlsx',
#    '238 будни.xlsx',
#    '685 будни.xlsx',
#    '82 будни (март-апрель).xlsx',
#    '185 будни.xlsx',
#    'М9 будни.xlsx',
#    '136 будни.xlsx',
#    '677К будни (май).xlsx',
#    '50 будни.xlsx',
#    '98 будни.xlsx',
#    '50 выходные.xlsx',
#    'С543 выходные.xlsx',
#    '696 выходные.xlsx',
#    '746 выходные.xlsx',
#    '696 будни.xlsx',
#    'С6 выходные.xlsx',
#    '685 выходные.xlsx',
#    '71 будни.xlsx',
#    '843 будни.xlsx',
#    '176 выходные.xlsx',
#    '628 будни.xlsx',
#    '603 будни.xlsx',
#    '928 выходные.xlsx',
#    '134 будни.xlsx',
#    '185 выходные.xlsx',
#    '628 выходные.xlsx',
#    '284 будни.xlsx',
#    '181 выходные.xlsx',
#    'Н9 выходные.xlsx',
#    '238К будни.xlsx',
#    '278 выходные.xlsx',
#    '40 будни.xlsx',
#    '181 будни.xlsx',
#    '603 выходные.xlsx',
#    '61 выходные.xlsx',
#    '278 будни.xlsx',
#    '183 выходные.xlsx',
#    'С543 будни.xlsx',
#    '176 будни.xlsx',
#    '71 выходные.xlsx',
#    '605 будни.xlsx',
#    '843 выходные.xlsx',
#    '677К выходные (май).xlsx',
#    'Н6 будни.xlsx',
#    '98 выходные.xlsx',
#    '82 выходные (май).xlsx',
#    '183 будни.xlsx',
#    '774 будни.xlsx',
#    '867 выходные.xlsx',
#    '124 будни.xlsx',
#    '78 будни.xlsx',
#    '238 выходные.xlsx',
#    '134 выходные.xlsx',
#    '78 выходные.xlsx',
#    'С6 будни.xlsx',
#    'Н6 выходные.xlsx',
#    '124 выходные.xlsx',
#    '61 будни.xlsx',
#    '82 будни (май).xlsx',
#    '238К выходные.xlsx',
#    '82 выходные (март-апрель).xlsx',
#    '928 будни.xlsx',
#    '22 выходные.xlsx',
#    'С532 будни.xlsx',
#    '746 будни.xlsx']),
#  ('/Users/tatiana/Desktop/Безбилетнки/Пассажиропоток/Черёмушкинский авт. парк',
#   [],
#   ['121 выходные.xlsx',
#    '944 будни.xlsx',
#    'С918 будни.xlsx',
#    'С918 выходные.xlsx',
#    'С5 будни.xlsx',
#    '146 выходные.xlsx',
#    '699 будни.xlsx',
#    '224 будни.xlsx',
#    '434 выходные.xlsx',
#    'С755 будни.xlsx',
#    '648 будни.xlsx',
#    '968 выходные.xlsx',
#    'Т60 будни.xlsx',
#    'Т60 выходные.xlsx',
#    '49 выходные.xlsx',
#    '142 будни.xlsx',
#    'С2 выходные.xlsx',
#    '616 выходные.xlsx',
#    '639 будни (март).xlsx',
#    '273 будни.xlsx',
#    '153 будни.xlsx',
#    '712 будни.xlsx',
#    '648 выходные.xlsx',
#    '965 будни.xlsx',
#    '244 выходные.xlsx',
#    'С755 выходные.xlsx',
#    '965 выходные.xlsx',
#    'С2 будни.xlsx',
#    '968 будни.xlsx',
#    '752 выходные.xlsx',
#    'С5 выходные.xlsx',
#    '434 будни.xlsx',
#    '716 будни.xlsx',
#    '153 выходные.xlsx',
#    '752 будни.xlsx',
#    '146 будни.xlsx',
#    '121 будни.xlsx',
#    '616 будни.xlsx',
#    '944 выходные.xlsx',
#    '639 выходные (март).xlsx']),
#  ('/Users/tatiana/Desktop/Безбилетнки/Пассажиропоток/Западный (5,15)',
#   [],
#   ['229 выходные 00.xlsx',
#    'Т65 будни.xlsx',
#    'Е30 выходные (апрель-май).xlsx',
#    'М1 будни.xlsx',
#    '199 выходные У1.xlsx',
#    '640 будни.xlsx',
#    '210 выходные.xlsx',
#    '207 выходные.xlsx',
#    '678 выходные.xlsx',
#    '2 будни.xlsx',
#    '155 выходные.xlsx',
#    'С339 будни.xlsx',
#    '268К выходные.xlsx',
#    '829 выходные У1.xlsx',
#    '652 выходные.xlsx',
#    '152 выходные.xlsx',
#    '229 будни У1.xlsx',
#    '130 будни Д1.xlsx',
#    '267 выходные.xlsx',
#    '268 будни.xlsx',
#    '654 будни.xlsx',
#    'С369 будни.xlsx',
#    'Т выходные.xlsx',
#    '178 выходные.xlsx',
#    '653 будни У2.xlsx',
#    '379 будни (весна 2022).xlsx',
#    '127 будни.xlsx',
#    '110 будни.xlsx',
#    '896 выходные.xlsx',
#    '865 будни У1.xlsx',
#    'М3 выходные.xlsx',
#    '43 выходные.xlsx',
#    'Т29 будни.xlsx',
#    '104 будни 00.xlsx',
#    'М35 выходные.xlsx',
#    'Т19 будни.xlsx',
#    '251К будни.xlsx',
#    '199 будни 00.xlsx',
#    '829 будни 00.xlsx',
#    '253 будни У1.xlsx',
#    '638 выходные.xlsx',
#    '60 будни.xlsx',
#    'М3 будни.xlsx',
#    '865 выходные 00.xlsx',
#    '732 выходные.xlsx',
#    '178 будни.xlsx',
#    '846 выходные.xlsx',
#    '678 будни.xlsx',
#    '687 будни.xlsx',
#    '800 выходные 00.xlsx',
#    'М35 будни.xlsx',
#    '653 будни 00.xlsx',
#    '253 выходные.xlsx',
#    '846 будни.xlsx',
#    '930 будни.xlsx',
#    '104 будни Д1.xlsx',
#    '43 будни.xlsx',
#    '337 будни.xlsx',
#    'С11 выходные.xlsx',
#    'П115 выходные.xlsx',
#    '2 выходные.xlsx',
#    '741 выходные.xlsx',
#    'С339 выходные.xlsx',
#    '800 будни 00.xlsx',
#    '130 будни 00.xlsx',
#    '267 будни.xlsx',
#    '105 выходные.xlsx',
#    '470 выходные.xlsx',
#    '155 будни.xlsx',
#    '229 выходные У1.xlsx',
#    '741 будни.xlsx',
#    'Т будни.xlsx',
#    '681 будни.xlsx',
#    '199 выходные 00.xlsx',
#    '104 будни Д2.xlsx',
#    '687 выходные.xlsx',
#    '614 выходные.xlsx',
#    '470 будни.xlsx',
#    '268К будни.xlsx',
#    '757 выходные.xlsx',
#    '829 выходные 00.xlsx',
#    '173 будни.xlsx',
#    '732 будни.xlsx',
#    '229 будни 00.xlsx',
#    'С3 выходные.xlsx',
#    '614 будни.xlsx',
#    '743 выходные.xlsx',
#    'С11 будни.xlsx',
#    '652 будни 00.xlsx',
#    '96 выходные.xlsx',
#    '105 будни.xlsx',
#    '268 выходные.xlsx',
#    '865 будни 00.xlsx',
#    '251 выходные.xlsx',
#    'П115 будни.xlsx',
#    'Е30 будни (апрель-май).xlsx',
#    '829 будни У1.xlsx',
#    '743 будни.xlsx',
#    '199 будни У1.xlsx',
#    '654 выходные.xlsx',
#    '102 будни.xlsx',
#    '253 будни 00.xlsx',
#    '96 будни.xlsx',
#    'С3 будни.xlsx',
#    '212 выходные.xlsx',
#    '865 выходные У1.xlsx',
#    '130 будни Д2.xlsx',
#    '800 выходные У1.xlsx',
#    '127 выходные.xlsx',
#    '130 выходные.xlsx',
#    '251 будни.xlsx',
#    '638 будни.xlsx',
#    '104 воскресенье.xlsx',
#    'М1 выходные.xlsx',
#    '322 будни.xlsx',
#    '652 будни Д1.xlsx',
#    '137 выходные.xlsx',
#    '399 будни.xlsx',
#    '379 выходные (весна 2022).xlsx',
#    '653 выходные.xlsx',
#    '930 выходные.xlsx',
#    '210 будни.xlsx',
#    '800 будни У1.xlsx',
#    '640 выходные.xlsx',
#    '48 будни (март).xlsx',
#    '152 будни.xlsx',
#    '896 будни.xlsx',
#    '794 выходные.xlsx']),
#  ('/Users/tatiana/Desktop/Безбилетнки/Пассажиропоток/Центральный (8)',
#   [],
#   ['С364-будни(март ) 14.03.22-18.03.22.xlsx',
#    'Н2 выходные (апрель-май).xlsx',
#    'С263-будни(весна).xlsx',
#    '260-будни(весна).xlsx',
#    '42-будни(апрель-май0.xlsx',
#    '116-выходные(февраль-март).xlsx',
#    '42-выходные(февраль-март).xlsx',
#    'Н2 будни(апрель- май).xlsx',
#    '116-будни(февраль-март) (укороты не по трассе).xlsx',
#    '345-выходные(март).xlsx',
#    '42-будни(февраль-март).xlsx',
#    '157-будни(апрель).xlsx',
#    '116-выходные(апрель-май).xlsx',
#    '1-будни(февраль-март).xlsx',
#    '175-выходные(весна).xlsx',
#    '45-будни(апрель-май).xlsx',
#    'С249-будни(весна).xlsx',
#    '220-будни(март-апрель).xlsx',
#    '42-выходные(май).xlsx',
#    '67-будни(весна).xlsx',
#    'С364-выходные(март).xlsx',
#    'М2-будни(февраль-март).xlsx',
#    'Т54-будни(май).xlsx',
#    '825-выходные(весна).xlsx',
#    'М2-выходные(февраль-март).xlsx',
#    'Б-выходные(апрель).xlsx',
#    'Б-будни(май).xlsx',
#    '345-будни(апрель) без у2 и у3.xlsx',
#    '157-будни(май).xlsx',
#    'Т54-выходные(май).xlsx',
#    '345-будни (март)(без у2 и у3).xlsx',
#    'Б-выходные(май).xlsx',
#    '45-выходные(апрель-май).xlsx',
#    'Б-будни(март).xlsx',
#    '67-выходные(весна).xlsx',
#    'Б-будни(апрель).xlsx',
#    'Т54-выходные(апрель).xlsx',
#    '157-выходные(весна).xlsx',
#    'Б-выходные(март).xlsx',
#    'Т54-будни(апрель).xlsx',
#    'Т54-выходные(март).xlsx',
#    '113-выходные(весна).xlsx',
#    '825-будни(весна).xlsx',
#    '609-будни(январь-май).xlsx',
#    '113-будни(весна).xlsx',
#    '175-будни(весна).xlsx',
#    '345-выходные(апрель) без у2.xlsx',
#    'Т54-будни(март).xlsx',
#    '260-выходные(весна).xlsx',
#    '345-будни(май) без у2 и у3.xlsx',
#    '116-будни(апрель-май).xlsx']),
#  ('/Users/tatiana/Desktop/Безбилетнки/Безбилетники по остановкам',
#   [],
#   ['Восточный филиал.xlsx'])]

# %% [markdown]
# ## Функция `open()`

# %% [markdown]
# ```python
# open('путь к файлу/название файла.расширение', mode = 'режим', encoding = 'кодировка')
# ```

# %% [markdown]
# **Расширения** с которыми работает функция `open()`:
# + .txt
# + .csv
# + .tsv
# + .html
# + .xlsx
# + .pdf
# + и д.р.

# %% [markdown]
# **Режими** работы с файлами, которые можно использовать с функцией `open()`:
# + `mode='r'` — _read,  **чтение**_. При отсутствии указанного файла выдается ошибка. Это режим по умолчанию
# + `mode='w'` — _write, **запись**_. При отсутствии указанного файла создается новый. При наличии файла содержимое перезаписывается
# + `mode='a'` — _append, **дозапись**_. При отсутствии указанного файла создается новый. При наличии файла новое содержимое дозаписывается после имеющегося
# + и д.р.

# %% [markdown]
# **Кодировки** файлов:
# + utf-8
# + latin-1
# + ISO-8859-5
# + dos
# + и д.р.

# %% [markdown]
# ## Открытие файла

# %% [markdown]
# Функция `open()` возвращает файловый объект
#
# Такой объект называется file handle или дескриптор файла

# %%
f = open('example.txt')
f
# Out:
# <_io.TextIOWrapper name='example.txt' mode='r' encoding='UTF-8'>

# %% [markdown]
# ```
# <<служебная информация> name='название файла.расширение' mode='режим' encoding='кодировка'>
# ```

# %% [markdown]
# ## Чтение файла

# %%
f = open('example.txt')
print(f.read())
f.close()
# Out:
# 1 one
# 2 two
# 3 three
# 4 four
# 5 five
# 6 six
# 7 seven
# 8 eight

# %% [markdown]
# После того как файл закрыт читать его уже нельзя

# %%
f.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/qg/08y10w1n1mb78ynxwmg8fmp00000gn/T/ipykernel_24212/3059900045.py in <module>
# ----> 1 f.read()
#
# ValueError: I/O operation on closed file.

# %% [markdown]
# ## Оптимальная работа с файлами

# %% [markdown]
# Хорошим тоном при работе с файлами считается открывать их с помощью ключевого слова `with`. Преимущество этого способа в том, что файл закроется автоматически, когда закончатся вложенные операции.

# %% [markdown]
# ```python
# with open('путь к файлу/название.расширение', mode = 'режим', encoding = 'кодировка') as <псеводним файла>:
#   ...
# ```

# %% [markdown]
# ### Чтение файла

# %%
with open('example.txt', encoding = 'utf-8') as infile:
    read_data = infile.read()

# %%
print(read_data)
# Out:
# 1 one
# 2 two
# 3 three
# 4 four
# 5 five
# 6 six
# 7 seven
# 8 eight

# %% [markdown]
# ## Построчное чтение файла `mode = 'r'`

# %% [markdown]
# ### `.readline()`

# %%
f = open('example.txt', encoding = 'utf-8')
f.readline()
# Out:
# '1 one\n'

# %%
f.readline()
# Out:
# '2 two\n'

# %%
f.readline()
# Out:
# '3 three\n'

# %%
f.close()

# %% [markdown]
# ### через `for`

# %% [markdown]
# ```python
# with open('путь к файлу', mode = 'режим', encoding = 'кодировка') as <псеводним файла>:
#   for <строчка> in <псеводним файла>:
#     print(<строчка>)
# ```

# %%
s = '_one '
s.strip('_').strip()
# Out:
# 'one'

# %%
s = '_one_'
s.lstrip('_')
# Out:
# 'one_'

# %%
s = '_one_'
s.lstrip('_')

# %%
s = 'h kfijd fo'
s.replace(' ', '')
# Out:
# 'hkfijdfo'

# %%
with open('example.txt', encoding = 'utf-8') as infile:
    for l in infile:
        print(l.rstrip('\n'))
# Out:
# 1 one
# 2 two
# 3 three
# 4 four
# 5 five
# 6 six
# 7 seven
# 8 eight

# %% [markdown]
# ## Извлечение информации из файла

# %%
k = 0
ks = ''
with open('example.txt', mode = 'r', encoding = 'utf-8') as infile:
    for l in infile:
        s = l.strip().split()
        k+=int(s[0])
        ks+=s[1]+ ' '
print(k)
print(ks)
# Out:
# 36
# one two three four five six seven eight

# %% [markdown]
# ## Создание нового файла `mode = 'w'`

# %% [markdown]
# ```python
# with open('путь/название файла.расширение', mode = 'w', encoding = 'кодировка') as <псеводним файла>:
#   print(<то что хотим записать в файл>, file=<псеводним файла>)
# ```

# %%
with open('example_writing.txt', mode = 'w', encoding = 'utf-8') as outfile:
    print(k, file=outfile)

# %%
'/Users/tatiana/Downloads/example_writing.txt'

# %% [markdown]
# ## Дозаписываем в файла `mode = 'a'`

# %% [markdown]
# ```python
# with open('путь/название файла.расширение', mode = 'a', encoding = 'кодировка') as <псеводним файла>:
#   print(<то что хотим записать в файл>, file=<псеводним файла>)
# ```

# %%
with open('example_writing.txt', mode = 'a', encoding = 'utf-8') as outfile:
  print(ks, file=outfile)

# %%
with open('example_writing2.txt', mode = 'w', encoding = 'utf-8') as outfile:
  print(ks, file=outfile)

# %% [markdown]
# ## Практика

# %% [markdown]
# ### Задание 1

# %% [markdown]
# Посчитайте частотность отправленных писем по часам **mbox.txt**

# %%
d = {}
with open('mbox.txt', mode = 'r', encoding = 'utf-8') as infile:
    for l in infile:
        if l.startswith('Date: ') and l.endswith(')\n'):
            l = l.split()[2][:2]
            if l in d:
                d[l]+=1
            else:
                d[l]=1
print(d)
# Out:
# {'09': 164, '18': 52, '16': 165, '15': 178, '14': 152, '11': 149, '10': 183, '07': 41, '06': 45, '04': 25, '19': 48, '17': 96, '13': 119, '12': 109, '08': 78, '05': 11, '03': 17, '02': 13, '20': 29, '22': 29, '21': 37, '00': 24, '23': 16, '01': 10}

# %% [markdown]
# ### Задание 2

# %% [markdown]
# Посчитайте частотность слов в текстовом файле **oblomov.txt** (без учета стоп-слов и знаков пунктуации)

# %% [markdown]
# Стоп-слова и символы пунктуации можно получить из модуля `nltk`

# %%
import nltk

from string import punctuation

punct = str(punctuation)
print(punct)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
punct.append('')

# %%
import re
k = 'kfdjlkgfjb;lfj4,]'
punct_re = '[%s]+'% re.escape(punct) #функция экранирования специальных символов
a = re.sub(punct_re, '', k)
a
# Out:
# 'kfdjlkgfjblfj4'

# %%
punct_re
# Out:
# '[!"\\#\\$%\\&\'\\(\\)\\*\\+,\\-\\./:;<=>\\?@\\[\\\\\\]\\^_`\\{\\|\\}\\~]+'

# %%
from nltk.corpus import stopwords

stops = set(stopwords.words('russian'))
print(stops)
# Out:
# {'уж', 'здесь', 'конечно', 'совсем', 'теперь', 'их', 'на', 'один', 'почти', 'его', 'том', 'быть', 'вы', 'много', 'нас', 'может', 'ней', 'ей', 'два', 'через', 'меня', 'об', 'еще', 'был', 'этом', 'тебя', 'этого', 'другой', 'иногда', 'ведь', 'нибудь', 'они', 'между', 'не', 'чуть', 'даже', 'куда', 'до', 'вот', 'то', 'а', 'при', 'ж', 'такой', 'будто', 'ни', 'нее', 'хоть', 'моя', 'чтобы', 'надо', 'было', 'за', 'со', 'ли', 'у', 'тоже', 'все', 'она', 'была', 'чем', 'раз', 'того', 'ему', 'или', 'него', 'для', 'зачем', 'там', 'вам', 'о', 'вас', 'какая', 'где', 'эти', 'наконец', 'больше', 'нельзя', 'когда', 'я', 'более', 'после', 'без', 'тем', 'же', 'потом', 'кто', 'мой', 'им', 'этой', 'нет', 'и', 'чтоб', 'мне', 'во', 'что', 'перед', 'тогда', 'потому', 'от', 'всю', 'тот', 'лучше', 'он', 'всего', 'но', 'из', 'какой', 'над', 'опять', 'сейчас', 'с', 'про', 'да', 'чего', 'есть', 'ним', 'были', 'впрочем', 'три', 'тут', 'только', 'ну', 'хорошо', 'себя', 'разве', 'эту', 'бы', 'так', 'ее', 'будет', 'себе', 'можно', 'сам', 'если', 'ничего', 'уже', 'в', 'свою', 'ты', 'этот', 'вдруг', 'них', 'как', 'всегда', 'к', 'под', 'по', 'никогда', 'всех', 'мы'}

# %%
stops_norm = set([morph.parse(word)[0].normal_form for word in stops])
stops_norm
# Out:
# {'а',
#  'без',
#  'более',
#  'большой',
#  'будто',
#  'бы',
#  'быть',
#  'в',
#  'вдруг',
#  'ведь',
#  'весь',
#  'вот',
#  'впрочем',
#  'всегда',
#  'всё',
#  'вы',
#  'где',
#  'да',
#  'даже',
#  'два',
#  'для',
#  'до',
#  'другой',
#  'если',
#  'есть',
#  'ещё',
#  'ж',
#  'же',
#  'за',
#  'зачем',
#  'здесь',
#  'и',
#  'из',
#  'или',
#  'иногда',
#  'к',
#  'как',
#  'какой',
#  'когда',
#  'конечно',
#  'кто',
#  'куда',
#  'ли',
#  'между',
#  'много',
#  'можно',
#  'мой',
#  'мочь',
#  'мы',
#  'на',
#  'над',
#  'надо',
#  'наконец',
#  'не',
#  'нельзя',
#  'нет',
#  'ни',
#  'нибыть',
#  'никогда',
#  'ничего',
#  'но',
#  'ну',
#  'о',
#  'один',
#  'он',
#  'она',
#  'они',
#  'опять',
#  'от',
#  'перед',
#  'по',
#  'под',
#  'после',
#  'потом',
#  'потому',
#  'почти',
#  'при',
#  'про',
#  'раз',
#  'разве',
#  'с',
#  'сам',
#  'свой',
#  'себя',
#  'сейчас',
#  'совсем',
#  'так',
#  'такой',
#  'там',
#  'тем',
#  'теперь',
#  'то',
#  'тогда',
#  'тоже',
#  'только',
#  'тот',
#  'три',
#  'тут',
#  'ты',
#  'у',
#  'уж',
#  'уже',
#  'хороший',
#  'хорошо',
#  'хоть',
#  'чем',
#  'через',
#  'что',
#  'чтоб',
#  'чтобы',
#  'чуть',
#  'это',
#  'этот',
#  'я'}

# %% [markdown]
# Еще вам понадобится преобразовать слова в начальную форму, чтобы условное слово "корова" и "коровы" считалось как одно. Для этого вам понадобится модуль `pymorphy2`

# %%
import pymorphy2
morph = pymorphy2.MorphAnalyzer()

#word = "коровы"
word = "стали"
p = morph.parse(word)[1]
print(p.normal_form)
# Out:
# сталь

# %%
morph.parse(word)
# Out:
# [Parse(word='стали', tag=OpencorporaTag('VERB,perf,intr plur,past,indc'), normal_form='стать', score=0.975342, methods_stack=((DictionaryAnalyzer(), 'стали', 945, 4),)),
#  Parse(word='стали', tag=OpencorporaTag('NOUN,inan,femn sing,gent'), normal_form='сталь', score=0.010958, methods_stack=((DictionaryAnalyzer(), 'стали', 13, 1),)),
#  Parse(word='стали', tag=OpencorporaTag('NOUN,inan,femn plur,nomn'), normal_form='сталь', score=0.005479, methods_stack=((DictionaryAnalyzer(), 'стали', 13, 6),)),
#  Parse(word='стали', tag=OpencorporaTag('NOUN,inan,femn sing,datv'), normal_form='сталь', score=0.002739, methods_stack=((DictionaryAnalyzer(), 'стали', 13, 2),)),
#  Parse(word='стали', tag=OpencorporaTag('NOUN,inan,femn sing,loct'), normal_form='сталь', score=0.002739, methods_stack=((DictionaryAnalyzer(), 'стали', 13, 5),)),
#  Parse(word='стали', tag=OpencorporaTag('NOUN,inan,femn plur,accs'), normal_form='сталь', score=0.002739, methods_stack=((DictionaryAnalyzer(), 'стали', 13, 9),))]

# %%
morph.parse(word)[0].normal_form
# Out:
# 'корова'

# %% [markdown]
# 1. Создадим пустой словарь, куда записываем слова и частотность
# 2. Открываем файл в режиме чтения
# 3. Считываем файл построчно
# 4. Делаем всю строку в одном регистре
# 5. Удаляем пунктуацию
# 6. Приведение слова к начальной форме
# 6. Удаляем стоп-слова (из лематизированного)
# 8. Записываем слово и его частоту в словарь

# %%
"это" in stops
# Out:
# False

# %%
import re
d = {}
with open('oblomov.txt', mode = 'r', encoding = 'utf-8') as infile:
    for l in infile:
        l = l.lower()
        l = re.sub(punct_re, '', l)
        l = [morph.parse(word)[0].normal_form for word in l.split()]
        l = [word for word in l if word not in stops_norm]
        for i in l:
            if i in d:
                d[i]+=1
            else:
                d[i]=1
print(d)
# Out:
# {'гороховый': 1, 'улица': 1, 'больший': 2, 'дом': 15, 'народонаселение': 1, 'который': 16, 'стать': 8, 'целый': 4, 'уездный': 1, 'город': 1, 'лежать': 14, 'утром': 2, 'постель': 6, 'квартира': 7, 'илья': 25, 'ильич': 25, 'обломов': 34, 'человек': 7, 'год': 5, 'тридцать': 1, 'двухтреха': 1, 'род': 3, 'среднее': 1, 'рост': 1, 'приятный': 2, 'наружность': 1, 'тёмно-серый': 1, 'глаз': 6, 'отсутствие': 1, 'всякий': 7, 'определённый': 2, 'идея': 2, 'сосредоточенность': 1, 'черта': 2, 'лицо': 15, 'мысль': 2, 'гулять': 1, 'вольный': 1, 'птица': 3, 'порхать': 1, 'садиться': 1, 'полуотворить': 1, 'губа': 1, 'прятаться': 1, 'складка': 3, 'лоб': 3, 'пропадать': 1, 'теплиться': 1, 'ровный': 1, 'свет': 2, 'беспечность': 2, 'переходить': 2, 'поза': 1, 'тело': 5, 'шлафрок': 1, 'взгляд': 4, 'помрачаться': 1, 'выражение': 2, 'усталость': 2, 'скука': 2, 'минута': 4, 'согнать': 1, 'мягкость': 2, 'господствующий': 2, 'основный': 1, 'душа': 4, 'открыто': 1, 'ясно': 1, 'светиться': 1, 'улыбка': 2, 'каждый': 4, 'движение': 4, 'голова': 2, 'рука': 7, 'поверхностно': 1, 'наблюдательный': 1, 'холодный': 1, 'взглянуть': 2, 'мимоходом': 1, 'с
алый': 1, 'природа': 1, 'плод': 1, 'занавес': 1, 'ковёр': 2, 'несколько': 3, 'картина': 5, 'бронза': 1, 'фарфор': 1, 'множество': 1, 'мелочь': 2, 'опытный': 1, 'чистый': 1, 'вкус': 2, 'беглый': 1, 'прочесть': 2, 'желание': 1, 'коекак': 1, 'соблюсти': 1, 'decorum1': 1, 'неизбежный': 1, 'приличие': 1, 'лишь': 2, 'отделаться': 1, 'хлопотать': 2, 'убирать': 5, 'утончить': 1, 'удовольствоваться': 1, 'тяжёлый': 1, 'неграциозный': 1, 'стул': 3 ...

# %% [markdown]
# 8. Отсортируем словарь по значениям по возрастанию

# %%
sorted_tuple = sorted(d.items(), key = lambda x: x[1], reverse = True)
sorted_tuple
# Out:
# [('—', 208),
#  ('захар', 51),
#  ('обломов', 34),
#  ('илья', 25),
#  ('ильич', 25),
#  ('сказать', 24),
#  ('говорить', 19),
#  ('который', 16),
#  ('дом', 15),
#  ('лицо', 15),
#  ('лежать', 14),
#  ('письмо', 12),
#  ('барин', 12),
#  ('видеть', 10),
#  ('встать', 9),
#  ('знать', 9),
#  ('стать', 8),
#  ('комната', 8),
#  ('кабинет', 8),
#  ('дело', 8),
#  ('староста', 8),
#  ('вон', 8),
#  ('квартира', 7),
#  ('человек', 7),
#  ('всякий', 7),
#  ('рука', 7),
#  ('убрать', 7),
#  ('пыль', 7),
#  ('думать', 7),
#  ('бог', 7),
#  ('уйти', 7),
#  ('постель', 6),
#  ('глаз', 6),
#  ('день', 6),
#  ('стоять', 6),
#  ('деревня', 6),
#  ('сторона', 6),
#  ('спросить', 6),
#  ('год', 5),
#  ('тело', 5),
#  ('казаться', 5),
#  ('немой', 5),
#  ('халат', 5),
#  ('широкий', 5),
#  ('нога', 5),
#  ('диван', 5),
#  ('картина', 5),
#  ('убирать', 5),
#  ('слуга', 5),
#  ('стена', 5),
#  ('стол', 5),
#  ('подумать', 5),
#  ('давно', 5),
#  ('чай', 5),
#  ('сделать', 5),
#  ('серый', 5),
#  ('сюртук', 5),
#  ('старый', 5),
#  ('платок', 5),
#  ('неделя', 5),
#  ('клоп', 5),
#  ('набраться', 5),
#  ('готовый', 5),
#  ('целый', 4),
#  ('взгляд', 4),
#  ('минута', 4),
#  ('душа', 4),
#  ('каждый', 4),
#  ('движение', 4),
#  ('мягкий', 4),
#  ('забота', 4),
#  ('покойный', 4),
#  ('хотя', 4),
#  ('глядеть', 4),
#  ('паутина', 4),
#  ('тарелка', 4),
#  ('валяться', 4),
#  ('жить', 4),
#  ('книга', 4),
#  ('неприятный', 4),
#  ('писать', 4),
#  ('план', 4),
#  ('умыться', 4),
#  ('начать', 4),
#  ('бакенбарда', 4),
#  ('ворчать', 4),
#  ('отвечать', 4),
#  ('пойти', 4),
#  ('дверь', 4),
#  ('посмотреть', 4),
#  ('ах', 4),
#  ('угол', 4),
#  ('выдумать', 4),
#  ('завтра', 4),
#  ('счёты', 4),
#  ('деньга', 4),
#  ('род', 3),
#  ('птица', 3),
#  ('складка', 3),
#  ('лоб', 3),
#  ('долго', 3),
#  ('вообще', 3),
#  ('плечо', 3),
#  ('идти', 3),
#  ('ходить', 3),
#  ('жилет', 3),
#  ('пол', 3),
#  ('необходимость', 3),
#  ('хотеть', 3),
#  ('первый', 3),
#  ('красный', 3),
#  ('дерево', 3),
#  ('несколько', 3),
#  ('стул', 3),
#  ('точно', 3),
#  ('хозяин', 3),
#  ('спрашивать', 3),
#  ('предмет', 3),
#  ('скорее', 3),
#  ('память', 3),
#  ('очень', 3),
#  ('час', 3),
#  ('досада', 3),
#  ('получить', 3),
#  ('третий', 3),
#  ('разный', 3),
#  ('новый', 3),
#  ('ничто', 3),
#  ('пора', 3),
#  ('послышаться', 3),
#  ('напоминать', 3),
#  ('старинный', 3),
#  ('отчий', 3),
#  ('звать', 3),
#  ('поди', 3),
#  ('ломать', 3),
#  ('нужный', 3),
#  ('найти', 3),
#  ('прийти', 3),
#  ('заметить', 3),
#  ('везде', 3),
#  ('коли', 3),
#  ('жизнь', 3),
#  ('взять', 3),
#  ('мышь', 3),
#  ('сор', 3),
#  ('возразить', 3),
#  ('сын', 3),
#  ('давать', 3),
#  ('приставать', 3),
#  ('больший', 2),
#  ('утром', 2),
#  ('приятный', 2),
#  ('определённый', 2),
#  ('идея', 2),
#  ('черта', 2),
#  ('мысль', 2),
#  ('свет', 2),
#  ('беспечность', 2),
#  ('переходить', 2),
#  ('выражение', 2),
#  ('усталость', 2),
#  ('скука', 2),
#  ('мягкость', 2),
#  ('господствующий', 2),
#  ('улыбка', 2),
#  ('голова', 2),
#  ('взглянуть', 2),
#  ('должный', 2),
#  ('цвет', 2),
#  ('както', 2),
#  ('слишком', 2),
#  ('изнеженный', 2),
#  ('являться', 2),
#  ('редко', 2),
#  ('тревога', 2),
#  ('редкий', 2),
#  ('намерение', 2),
#  ('дремота', 2),
#  ('костюм', 2),
#  ('материя', 2),
#  ('восточный', 2),
#  ('намёк', 2),
#  ('весьма', 2),
#  ('место', 2),
#  ('естественный', 2),
#  ('достоинство', 2),
#  ('чувствовать', 2),
#  ('любить', 2),
#  ('туфля', 2),
#  ('непременно', 2),
#  ('служить', 2),
#  ('бюро', 2),
#  ('шёлковый', 2),
#  ('красивый', 2),
#  ('ковёр', 2),
#  ('мелочь', 2),
#  ('вкус', 2),
#  ('прочесть', 2),
#  ('лишь', 2),
#  ('хлопотать', 2),
#  ('этажерка', 2),
#  ('носить', 2),
#  ('смотреть', 2),
#  ('холодное', 2),
#  ('воззрение', 2),
#  ('вид', 2),
#  ('какихнибудь', 2),
#  ('пятно', 2),
#  ('забытый', 2),
#  ('полотенце', 2),
#  ('вчерашний', 2),
#  ('б', 2),
#  ('дветереть', 2),
#  ('развернуть', 2),
#  ('газета', 2),
#  ('чернильница', 2),
#  ('перо', 2),
#  ('видно', 2),
#  ('бросить', 2),
#  ('проснуться', 2),
#  ('обыкновение', 2),
#  ('рано', 2),
#  ('сильно', 2),
#  ('озаботить', 2),
#  ('тоска', 2),
#  ('ум', 2),
#  ('п', 2),
#  ('мера', 2),
#  ('тотчас', 2),
#  ('полчаса', 2),
#  ('мешать', 2),
#  ('лёжа', 2),
#  ('пробить', 2),
#  ('вслух', 2),
#  ('дать', 2),
#  ('воля', 2),
#  ('сначала', 2),
#  ('ворчание', 2),
#  ('собака', 2),
#  ('спрыгнуть', 2),
#  ('лежанка', 2),
#  ('время', 2),
#  ('погрузить', 2),
#  ('войти', 2),
#  ('торчать', 2),
#  ('клочок', 2),
#  ('стараться', 2),
#  ('образ', 2),
#  ('платье', 2),
#  ('слабый', 2),
#  ('воспоминание', 2),
#  ('ливрея', 2),
#  ('господин', 2),
#  ('гость', 2),
#  ('единственный', 2),
#  ('старик', 2),
#  ('барский', 2),
#  ('быт', 2),
#  ('остаться', 2),
#  ('предание', 2),
#  ('каприз', 2),
#  ('право', 2),
#  ('незаметно', 2),
#  ('друг', 2),
#  ('дорожить', 2),
#  ('задумчивость', 2),
#  ('прыжок', 2),
#  ('сильный', 2),
#  ('погрузиться', 2),
#  ('немного', 2),
#  ('захрипеть', 2),
#  ('голос', 2),
#  ('слово', 2),
#  ('никакой', 2),
#  ('положить', 2),
#  ('бумага', 2),
#  ('сей', 2),
#  ('починить', 2),
#  ('изломаться', 2),
#  ('доказывать', 2),
#  ('неудовольствие', 2),
#  ('удивление', 2),
#  ('упрёк', 2),
#  ('виноватый', 2),
#  ('делать', 2),
#  ('указать', 2),
#  ('указывать', 2),
#  ('хлеб', 2),
#  ('анисья', 2),
#  ('шкаф', 2),
#  ('сидеть', 2),
#  ('поглядеть', 2),
#  ('вздохнуть', 2),
#  ('равнодушно', 2),
#  ('отозваться', 2),
#  ('нечистота', 2),
#  ('перебить', 2),
#  ('бывать', 2),
#  ('чисто', 2),
#  ('отец', 2),
#  ('корка', 2),
#  ('баба', 2),
#  ('ступать', 2),
#  ('тронуть', 2),
#  ('какнибыть', 2),
#  ('ужас', 2),
#  ('передний', 2),
#  ('вставать', 2),
#  ('чрез', 2),
#  ('управлять', 2),
#  ('съехать', 2),
#  ('распорядиться', 2),
#  ('переезжать', 2),
#  ('бок', 2),
#  ('гороховый', 1),
#  ('улица', 1),
#  ('народонаселение', 1),
#  ('уездный', 1),
#  ('город', 1),
#  ('тридцать', 1),
#  ('двухтреха', 1),
#  ('среднее', 1),
#  ('рост', 1),
#  ('наружность', 1),
#  ('тёмно-серый', 1),
#  ('отсутствие', 1),
#  ('сосредоточенность', 1),
#  ('гулять', 1),
#  ('вольный', 1),
#  ('порхать', 1),
#  ('садиться', 1),
#  ('полуотворить', 1),
#  ('губа', 1),
#  ('прятаться', 1),
#  ('пропадать', 1),
#  ('теплиться', 1),
#  ('ровный', 1),
#  ('поза', 1),
#  ('шлафрок', 1),
#  ('помрачаться', 1),
#  ('согнать', 1),
#  ('основный', 1),
#  ('открыто', 1),
#  ('ясно', 1),
#  ('светиться', 1),
#  ('поверхностно', 1),
#  ('наблюдательный', 1),
#  ('холодный', 1),
#  ('мимоходом', 1),
#  ('«добряк', 1),
#  ('простота»', 1),
#  ('глубокий', 1),
#  ('симпатичный', 1),
#  ('вглядываться', 1),
#  ('отойти', 1),
#  ('раздумье', 1),
#  ('румяный', 1),
#  ('смуглый', 1),
#  ('положительно', 1),
#  ('бледный', 1),
#  ('безразличный', 1),
#  ('обрюзгнуть', 1),
#  ('недостаток', 1),
#  ('воздух', 1),
#  ('судить', 1),
#  ('матовый', 1),
#  ('чересчур', 1),
#  ('белый', 1),
#  ('шея', 1),
#  ('маленький', 1),
#  ('пухлый', 1),
#  ('мужчина', 1),
#  ('встревожить', 1),
#  ('сдерживаться', 1),
#  ('также', 1),
#  ('лишённый', 1),
#  ('грация', 1),
#  ('лень', 1),
#  ('набегать', 1),
#  ('туча', 1),
#  ('туманиться', 1),
#  ('начинаться', 1),
#  ('игра', 1),
#  ('сомнение', 1),
#  ('печаль', 1),
#  ('испуг', 1),
#  ('застывать', 1),
#  ('форма', 1),
#  ('превращаться', 1),
#  ('разрешаться', 1),
#  ('вздох', 1),
#  ('замирать', 1),
#  ('апатия', 1),
#  ('домашний', 1),
#  ('персидский', 1),
#  ('настоящий', 1),
#  ('малый', 1),
#  ('европа', 1),
#  ('кисть', 1),
#  ('бархат', 1),
#  ('талия', 1),
#  ('поместительный', 1),
#  ('дважды', 1),
#  ('завернуться', 1),
#  ('рукав', 1),
#  ('неизменный', 1),
#  ('азиатский', 1),
#  ('мода', 1),
#  ('палец', 1),
#  ('утратить', 1),
#  ('первоначальный', 1),
#  ('свежесть', 1),
#  ('заменить', 1),
#  ('первобытный', 1),
#  ('лоск', 1),
#  ('благоприобретённый', 1),
#  ('сохранять', 1),
#  ('яркость', 1),
#  ('краска', 1),
#  ('прочность', 1),
#  ('ткань', 1),
#  ('иметь', 1),
#  ('тьма', 1),
#  ('неоценённый', 1),
#  ('гибкий', 1),
#  ('послушный', 1),
#  ('раб', 1),
#  ('покоряться', 1),
#  ('самомалейший', 1),
#  ('галстук', 1),
#  ('простор', 1),
#  ('приволье', 1),
#  ('длинный', 1),
#  ('опускать', 1),
#  ('попадать', 1),
#  ('сразу', 1),
#  ('лежание', 1),
#  ('больной', 1),
#  ('спать', 1),
#  ('случайность', 1),
#  ('устать', 1),
#  ('наслаждение', 1),
#  ('лентяй', 1),
#  ('нормальный', 1),
#  ('состояние', 1),
#  ('постоянно', 1),
#  ('наслать', 1),
#  ('спальня', 1),
#  ('приёмный', 1),
#  ('туда', 1),
#  ('заглядывать', 1),
#  ('мел', 1),
#  ('делаться', 1),
#  ('мебель', 1),
#  ('закрытый', 1),
#  ('чехол', 1),
#  ('штора', 1),
#  ('спустить', 1),
#  ('прекрасно', 1),
#  ('обить', 1),
#  ('ширма', 1),
#  ('вышитый', 1),
#  ('небывалый', 1),
#  ('природа', 1),
#  ('плод', 1),
#  ('занавес', 1),
#  ('бронза', 1),
#  ('фарфор', 1),
#  ('множество', 1),
#  ('опытный', 1),
#  ('чистый', 1),
#  ('беглый', 1),
#  ('желание', 1),
#  ('коекак', 1),
#  ('соблюсти', 1),
#  ('decorum1', 1),
#  ('неизбежный', 1),
#  ('приличие', 1),
#  ('отделаться', 1),
#  ('утончить', 1),
#  ('удовольствоваться', 1),
#  ('тяжёлый', 1),
#  ('неграциозный', 1),
#  ('шаткий', 1),
#  ('задок', 1),
#  ('осесться', 1),
#  ('вниз', 1),
#  ('наклеить', 1),
#  ('отстать', 1),
#  ('характер', 1),
#  ('ваза', 1),
#  ('однако', 1),
#  ('убранство', 1),
#  ('холодно', 1),
#  ('рассеянно', 1),
#  ('«кто', 1),
#  ('сюда', 1),
#  ('натащить', 1),
#  ('наставить', 1),
#  ('это»', 1),
#  ('собственность', 1),
#  ('осмотреть', 1),
#  ('внимательный', 1),
#  ('поражать', 1),
#  ('запущенность', 1),
#  ('небрежность', 1),
#  ('около', 1),
#  ('лепиться', 1),
#  ('фестон', 1),
#  ('напитать', 1),
#  ('зеркало', 1),
#  ('вместо', 1),
#  ('отражать', 1),
#  ('скрижаль', 1),
#  ('записывание', 1),
#  ('заметка', 1),
#  ('утро', 1),
#  ('ужин', 1),
#  ('солонка', 1),
#  ('обглодать', 1),
#  ('косточка', 1),
#  ('хлебный', 1),
#  ('крошка', 1),
#  ('прислонить', 1),
#  ('выкурить', 1),
#  ('трубка', 1),
#  ('никто', 1),
#  ('запылиться', 1),
#  ('полинялый', 1),
#  ('лишить', 1),
#  ('живой', 1),
#  ('след', 1),
#  ('человеческий', 1),
#  ('присутствие', 1),
#  ('правда', 1),
#  ('страница', 1),
#  ('покрыться', 1),
#  ('пожелтеть', 1),
#  ('нумереть', 1),
#  ('прошлогодний', 1),
#  ('обмакнуть', 1),
#  ('вырваться', 1),
#  ('жужжание', 1),
#  ('испуганный', 1),
#  ('муха', 1),
#  ('против', 1),
#  ('восемь', 1),
#  ('чемтый', 1),
#  ('попеременно', 1),
#  ('выступать', 1),
#  ('страх', 1),
#  ('одолевать', 1),
#  ('внутренний', 1),
#  ('борьба', 1),
#  ('помощь', 1),
#  ('накануне', 1),
#  ('содержание', 1),
#  ('известно', 1),
#  ('неприятность', 1),
#  ('неурожай', 1),
#  ('недоимка', 1),
#  ('уменьшение', 1),
#  ('доход', 1),
#  ('прошлый', 1),
#  ('последний', 1),
#  ('подействовать', 1),
#  ('сюрприз', 1),
#  ('легко', 1),
#  ('предстоять', 1),
#  ('средство', 1),
#  ('принятие', 1),
#  ('отдать', 1),
#  ('справедливость', 1),
#  ('заботливость', 1),
#  ('назад', 1),
#  ('создавать', 1),
#  ('перемена', 1),
#  ('улучшение', 1),
#  ('порядок', 1),
#  ('управление', 1),
#  ('имение', 1),
#  ('предполагаться', 1),
#  ('ввести', 1),
#  ('экономический', 1),
#  ('полицейский', 1),
#  ('далеко', 1),
#  ('обдуманный', 1),
#  ('ежегодно', 1),
#  ('повторяться', 1),
#  ('побуждать', 1),
#  ('деятельность', 1),
#  ('следовательно', 1),
#  ('нарушать', 1),
#  ('покой', 1),
#  ('сознавать', 1),
#  ('окончание', 1),
#  ('предпринять', 1),
#  ('чтонибыть', 1),
#  ('решительный', 1),
#  ('вознамериться', 1),
#  ('напиться', 1),
#  ('хорошенько', 1),
#  ('коечто', 1),
#  ('сообразить', 1),
#  ('записать', 1),
#  ('заняться', 1),
#  ('следовать', 1),
#  ('мучиться', 1),
#  ('рассудить', 1),
#  ('успеть', 1),
#  ('пить', 1),
#  ('приподняться', 1),
#  ('ложа', 1),
#  ('поглядывать', 1),
#  ('спускать', 1),
#  ('подобрать', 1),
#  ('половина', 1),
#  ('десятый', 1),
#  ('встрепенуться', 1),
#  ('совесть', 1),
#  ('и…', 1),
#  ('закричать', 1),
#  ('отделяться', 1),
#  ('небольшой', 1),
#  ('коридор', 1),
#  ('цепной', 1),
#  ('стук', 1),
#  ('откудато', 1),
#  ('обыкновенно', 1),
#  ('проводить', 1),
#  ('сидя', 1),
#  ('пожилой', 1),
#  ('прореха', 1),
#  ('мышка', 1),
#  ('откуда', 1),
#  ('рубашка', 1),
#  ('медный', 1),
#  ('пуговица', 1),
#  ('голый', 1),
#  ('колено', 1),
#  ('череп', 1),
#  ('необъятно', 1),
#  ('густой', 1),
#  ('русый', 1),
#  ('проседь', 1),
#  ('борода', 1),
#  ('изменить', 1),
#  ('данный', 1),
#  ('шиться', 1),
#  ('вывезти', 1),
#  ('образец', 1),
#  ('нравиться', 1),
#  ('полуформенный', 1),
#  ('одежда', 1),
#  ('некогда', 1),
#  ('провожать', 1),
#  ('церковь', 1),
#  ('представительница', 1),
#  ('глушь', 1),
#  ('умереть', 1),
#  ('фамильный', 1),
#  ('портрет', 1),
#  ('гденибыть', 1),
#  ('чердак', 1),
#  ('важность', 1),
#  ('фамилия', 1),
#  ('глохнуть', 1),
#  ('немногий', 1),
#  ('поэтому', 1),
#  ('дорога', 1),
#  ('коекакий', 1),
#  ('признак', 1),
#  ('сохраниться', 1),
#  ('манер', 1),
#  ('родитель', 1),
#  ('уважать', 1),
#  ('внутренне', 1),
#  ('проявление', 1),
#  ('господский', 1),
#  ('отживший', 1),
#  ('величие', 1),
#  ('воскрешать', 1),
#  ('молодость', 1),
#  ('покинуть', 1),
#  ('хроника', 1),
#  ('вести', 1),
#  ('нянька', 1),
#  ('мамка', 1),
#  ('передаваемый', 1),
#  ('родиться', 1),
#  ('когдато', 1),
#  ('богатый', 1),
#  ('знаменитый', 1),
#  ('беднеть', 1),
#  ('мельчать', 1),
#  ('потеряться', 1),
#  ('дворянский', 1),
#  ('поседеть', 1),
#  ('хранить', 1),
#  ('передавать', 1),
#  ('верный', 1),
#  ('минувший', 1),
#  ('святыня', 1),
#  ('детство', 1),
#  ('аристократический', 1),
#  ('украшение', 1),
#  ('замечать', 1),
#  ('молча', 1),
#  ('кашлянуть', 1),
#  ('помнить', 1),
#  ('потягиваться', 1),
#  ('пока', 1),
#  ('вспомнить', 1),
#  ('продолжать', 1),
#  ('проклятый', 1),
#  ('пройти', 1),
#  ('четверть', 1),
#  ('полно', 1),
#  ('встать…', 1),
#  ('дайка', 1),
#  ('внимание', 1),
#  ('неблагосклонный', 1),
#  ('посматривать', 1),
#  ('стоятьто', 1),
#  ('даром', 1),
#  ('неимение', 1),
#  ('потерять', 1),
#  ('охота', 1),
#  ('ездить', 1),
#  ('дунуть', 1),
#  ('ветер', 1),
#  ('горло', 1),
#  ('вполуоборот', 1),
#  ('среди', 1),
#  ('отсохнуть', 1),
#  ('постоять', 1),
#  ('подождать', 1),
#  ('залежаться', 1),
#  ('сыскать', 1),
#  ('вчера', 1),
#  ('видать', 1),
#  ('почтальон', 1),
#  ('принять', 1),
#  ('грязный', 1),
#  ('почему', 1),
#  ('похлопывать', 1),
#  ('вещь', 1),
#  ('корзина', 1),
#  ('завалиться', 1),
#  ('спинкато', 1),
#  ('призвать', 1),
#  ('столяр', 1),
#  ('изломать', 1),
#  ('век', 1),
#  ('когданибудь', 1),
#  ('счесть', 1),
#  ('противный', 1),
#  ('какиеть', 1),
#  ('нетерпение', 1),
#  ('упереться', 1),
#  ('прыгнуть', 1),
#  ('торопливый', 1),
#  ('крик', 1),
#  ('«захар', 1),
#  ('захар»', 1),
#  ('господь', 1),
#  ('отправляться', 1),
#  ('мучение', 1),
#  ('смерть', 1),
#  ('придерживаться', 1),
#  ('знак', 1),
#  ('неблаговоление', 1),
#  ('приходиться', 1),
#  ('вполглаза', 1),
#  ('видный', 1),
#  ('необъятный', 1),
#  ('ждать', 1),
#  ('вылететь', 1),
#  ('носовой', 1),
#  ('скорый', 1),
#  ('догадаться', 1),
#  ('строго', 1),
#  ('обнаружить', 1),
#  ('особенный', 1),
#  ('приказание', 1),
#  ('находить', 1),
#  ('вероятно', 1),
#  ('обходить', 1),
#  ('вокруг', 1),
#  ('ощупывать', 1),
#  ('терять', 1),
#  ('отворять', 1),
#  ('гостиный', 1),
#  ('искать', 1),
#  ('нету', 1),
#  ('разводить', 1),
#  ('озираться', 1),
#  ('сердито', 1),
#  ('конец', 1),
#  ('дожидаться', 1),
#  ('ответ', 1),
#  ('неловко', 1),
#  ('собственный', 1),
#  ('промах', 1),
#  ('быстро', 1),
#  ('повод', 1),
#  ('чистота', 1),
#  ('пылить', 1),
#  ('грязитый', 1),
#  ('поглядик', 1),
#  ('углахтый', 1),
#  ('делаю…', 1),
#  ('заговорить', 1),
#  ('обиженный', 1),
#  ('жалеть', 1),
#  ('пыльто', 1),
#  ('стирать', 1),
#  ('метуть', 1),
#  ('день…', 1),
#  ('середина', 1),
#  ('обедать', 1),
#  ('подмести', 1),
#  ('прибрать', 1),
#  ('словно', 1),
#  ('свадьбе…', 1),
#  ('прервать', 1),
#  ('потолок', 1),
#  ('ломоть', 1),
#  ('пожалуй', 1),
#  ('снисходительно', 1),
#  ('святой', 1),
#  ('чистить', 1),
#  ('снимаю…', 1),
#  ('обмести', 1),
#  ('рождество', 1),
#  ('перебрать', 1),
#  ('театр', 1),
#  ('бы…', 1),
#  ('уборка', 1),
#  ('ночью', 1),
#  ('покачать', 1),
#  ('окно', 1),
#  ('«ну', 1),
#  ('брат', 1),
#  ('нежели', 1),
#  ('сам»', 1),
#  ('«врать', 1),
#  ('мастер', 1),
#  ('мудрёный', 1),
#  ('жалкий', 1),
#  ('нет»', 1),
#  ('понимать', 1),
#  ('заводиться', 1),
#  ('моль', 1),
#  ('блоха', 1),
#  ('гадость', 1),
#  ('усмехнуться', 1),
#  ('усмешка', 1),
#  ('охватить', 1),
#  ('бровь', 1),
#  ('раздвинуться', 1),
#  ('расплыться', 1),
#  ('наивный', 1),
#  ('врать', 1),
#  ('бегать', 1),
#  ('ночь', 1),
#  ('слышать', 1),
#  ('тварь', 1),
#  ('кошка', 1),
#  ('молить', 1),
#  ('выразиться', 1),
#  ('недоверчивость', 1),
#  ('уверенность', 1),
#  ('упрямо', 1),
#  ('усмотреть', 1),
#  ('щёлка', 1),
#  ('влезть', 1),
#  ('«да', 1),
#  ('спаньё', 1),
#  ('клопа»', 1),
#  ('мести', 1),
#  ('выбирать', 1),
#  ('учить', 1),
#  ('твердить', 1),
#  ('вымести', 1),
#  ('перебирать', 1),
#  ('послать', 1),
#  ('напротив', 1),
#  ('настройщик', 1),
#  ('любо', 1),
#  ('девка…', 1),
#  ('немец', 1),
#  ('поглядитёкий', 1),
#  ('семья', 1),
#  ('кость', 1),
#  ('глодать', 1),
#  ('жена', 1),
#  ('дочь', 1),
#  ('платьишко', 1),
#  ('коротенький', 1),
#  ('поджимать', 1),
#  ('гусыни…', 1),
#  ('куча', 1),
#  ('старое', 1),
#  ('износить', 1),
#  ('зиму…', 1),
#  ('зря', 1),
#  ('наделать', 1),
#  ('сухарик', 1),
#  ('пиво', 1),
#  ('выпить', 1),
#  ('сквозь', 1),
#  ('зуб', 1),
#  ('плюнуть', 1),
#  ('рассуждать', 1),
#  ('скаредный', 1),
#  ('житие', 1),
#  ('нечего', 1),
#  ('разговаривать', 1),
#  ('иной', 1),
#  ('подик', 1),
#  ('настаивать', 1),
#  ('сегодня', 1),
#  ('управиться', 1),
#  ('вдвоемтый', 1),
#  ('нанять', 1),
#  ('перемыть', 1),
#  ('э', 1),
#  ('затея', 1),
#  ('рад', 1),
#  ('вызвать', 1),
#  ('разговор', 1),
#  ('забывать', 1),
#  ('деликатный', 1),
#  ('обобраться', 1),
#  ('хлопоты', 1),
#  ('хотеться', 1),
#  ('желать', 1),
#  ('сделаться', 1),
#  ('заводить', 1),
#  ('тяжба', 1),
#  ('начинать', 1),
#  ('требовать', 1),
#  ('сметание', 1),
#  ('мытьё', 1),
#  ('случай', 1),
#  ('громадный', 1),
#  ('возня', 1),
#  ('приводить', 1),
#  ('размышление', 1),
#  ('одиннадцать', 1),
#  ('скоро', 1),
#  ('известный', 1),
#  ('вслед', 1),
#  ('заниматься', 1),
#  ('сесть', 1),
#  ('воротиться', 1),
#  ('исписать', 1),
#  ('замаслить', 1),
#  ('тетрадка', 1),
#  ('кстати', 1),
#  ('изволить', 1),
#  ('поверить', 1),
#  ('заплатить', 1),
#  ('мясник', 1),
#  ('зеленщик', 1),
#  ('прачка', 1),
#  ('хлебник', 1),
#  ('просить', 1),
#  ('понемногу', 1),
#  ('подавать', 1),
#  ('прогонять', 1),
#  ('завтра…', 1),
#  ('долг', 1),
#  ('нынче', 1),
#  ('число', 1),
#  ('стоить', 1),
#  ('умытьсять', 1),
#  ('теперь…', 1),
#  ('кряхтеть', 1),
#  ('приподниматься', 1),
#  ('забыть', 1),
#  ('давеча', 1),
#  ('почивать', 1),
#  ('дворник', 1),
#  ('прислать', 1),
#  ('съехать…', 1),
#  ('разумеется', 1),
#  ('месяц', 1),
#  ('обещать', 1),
#  ('съезжать', 1),
#  ('полиция', 1),
#  ('пусть', 1),
#  ('решительно', 1),
#  ('переехать', 1),
#  ('тёплый', 1),
#  ('рабочий', 1),
#  ('будут…', 1),
#  ('«съезжать', 1),
#  ...]

# %%
list(d.items())[0][1]
# Out:
# 1

# %% [markdown]
# 9. Создадим файл, куда запишем таблицу-частотности в следующем форморате:
#
# ('слово', частота)
#
# Каждое на новой строке

# %%
with open('frq_oblomov.txt', mode = 'w', encoding = 'utf-8') as outfile:
    print(*sorted_tuple, file = outfile, sep = '\n')

# %% [markdown]
# ### Задание 3

# %% [markdown]
# Вам предоставили список людей, которые подали заявку на получение Пушкинской карты (**task2.csv**). Условием получения Пушкинской карты является возраст от 14 до 22 лет (2001-2007), включительно, и наличие гражданства РФ. Напишите программу, которая записывает в новый файл все строки, которые соответствуют людям из определенного города которые могут получить Пушкинскую карту.
#
# Итоговый файл должен называться: **pk_list_ГОРОД.csv**

# %%
city = input()
lst = []

with open('task2.csv', mode = 'r', encoding = 'utf-8') as infile:
    for l in infile:
        s = l.strip().split(',')
        if s[-1] == city and s[-2] == 'RU' and int(s[1][-4:]) in range(2001, 2008):
            lst.append(l.strip())

with open(f'pk_list_{city}.csv', mode = 'w', encoding = 'utf-8') as outfile:
    print(*lst, file = outfile, sep = '\n')
# Out:
# Москва

# %% [markdown]
# Посчитайте сколько людей из каждого города могут получить Пушкинскую карту

# %% [markdown]
# ### Задание 4

# %% [markdown]
# Нужно сделать подборку лучших упражнений (рейтинг не меньше 8.5) для спины (в описании есть слово "спины")из тех которые доступны в приложении для определенного уровня сложности и оборудования. Информация о всех упражнениях хранится в файле в формате **task3.tsv**.
#
#
# На каждой строке записана следующая информация об упражнении: Название, Тип, Часть тела, Оборудование, Уровень сложности, Рейтинг.
#
# *Например, "Barbell roll-out,Сила,Средняя часть спины,Штанга,Эксперт,9.8"*

# %% [markdown]
# Посчитайте средний рейтинг всех упражнений из приложения

# %% [markdown]
# ## Try except

# %% [markdown]
# Почти наверняка вы уже делали что-то, что приводило к сообщению об ошибке. Сегодня мы научимся их обрабатывать и писать собственные исключения - наши инструкции для Python, чтобы код не ломался, как только что-то пойдет не так.
#
# Например, мы хотим открывать файл по запросу от пользователя, но хотим обработать случай, когда пользователь введет неправильное название.

# %%
fname = input('Введите название файла: ')
fhand = open(fname) # введем название несуществующего файла
# Out:
# Введите название файла: filefile
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/qg/08y10w1n1mb78ynxwmg8fmp00000gn/T/ipykernel_24212/1619268622.py in <module>
#       1 fname = input('Введите название файла: ')
# ----> 2 fhand = open(fname) # введем название несуществующего файла
#
# FileNotFoundError: [Errno 2] No such file or directory: 'filefile'

# %% [markdown]
# Напишем блок `try`/`except`. Try будет исполняться до тех пор, пока что-то не сломается. Как только возникнет ошибка, ваша программа перейдет в часть `except` и выполнит действие, описанное в ней. Сообщения об ошибке выведено не будет.

# %%
name = input()

try:
    with open(name) as infile:
        for l in infile:
            print(l)
except:
    print('Файл не найден')
# Out:
# example.txt
# 1 one
#
# 2 two
#
# 3 three
#
# 4 four
#
# 5 five
#
# 6 six
#
# 7 seven
#
# 8 eight

# %% [markdown]
# Mожно не ломать код из-за ошибки, а просто продолжать его выполнять:
# ``` python
# try:
#     <инструкция>
# except:
#     pass

# %%
with open('tryexpect.txt') as infile:
        for l in infile:
            print(l)
# Out:
# 1
#
# one
#
# two
#
# 3
#
# 4
#
# 5
#
# six
#
# seven
#
# eight

# %%
s = 0
with open('tryexpect.txt') as infile:
        for l in infile:
            s+=int(l.strip())
print(s)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/qg/08y10w1n1mb78ynxwmg8fmp00000gn/T/ipykernel_24212/1217219568.py in <module>
#       2 with open('tryexpect.txt') as infile:
#       3         for l in infile:
# ----> 4             s+=int(l.strip())
#       5 print(s)
#
# ValueError: invalid literal for int() with base 10: 'one'

# %%
s = 0
with open('tryexpect.txt') as infile:
        for l in infile:
            try:
                s+=int(l.strip())
            except:
                pass
print(s)
# Out:
# 13

# %% [markdown]
# Но что делать, если мы хотим пропускать только определенный вид ошибок, но видеть сообщения об остальных? Try/except хороший инструмент для отладки кода. Давайте посмотрим, как называется ошибка при попытке вызова неопределенной переменной.

# %%
print(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/qg/08y10w1n1mb78ynxwmg8fmp00000gn/T/ipykernel_24212/1056546137.py in <module>
# ----> 1 print(y)
#
# NameError: name 'y' is not defined

# %% [markdown]
# Чтобы прописать инструкцию для конретного типа ошибок:
#
# ```python
# try:
#     <инструкция>
# except <тип ошибки>:
#     <инструкция>
# ```

# %%
try:
    print(y)
except NameError:
    print("Variable y is not defined")
except:
    print("Something else went wrong")

# %% [markdown]
# Иногда вам может понадобиться создавать свои исключения - персонализированные сообщения об ошибке, которые валидны только для вашей программы. Сделать это можно с помощью `raise Exception(<Ваше сообщение>)`

# %%
x = -1

if x < 0:
    raise Exception("Число не может быть отрицательным")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/qg/08y10w1n1mb78ynxwmg8fmp00000gn/T/ipykernel_24212/1586720503.py in <module>
#       2
#       3 if x < 0:
# ----> 4     raise "Число не может быть отрицательным"
#
# TypeError: exceptions must derive from BaseException

# %%
x = "hello"

if not type(x) is int:
    raise TypeError("Only integers are allowed")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/qg/08y10w1n1mb78ynxwmg8fmp00000gn/T/ipykernel_24212/1129330155.py in <module>
#       2
#       3 if not type(x) is int:
# ----> 4     raise TypeError("Only integers are allowed")
#
# TypeError: Only integers are allowed

# %% [markdown]
# ## Указание типов в Python

# %%
import typing #содержит описание всех типов данных

# %%
x:int =1

# %%
x = 'fhshl'

# %%
x
# Out:
# 'fhshl'

# %% [markdown]
# Если вы разметили все данные, то можно запустить линтер (специальный инструмент) по коду, который проверит, что тип данных соответствует указанаому, и не нужно будет выискивать, где вы допустили ошибку

# %% [markdown]
# Добавим к строке отступ:

# %%
def indent_right(s:str, amount:int) -> str:
    return " " * max(0, amount) + s

# %% [markdown]
# Описание с учетом None

# %%
from typing import Optional #для учета None

# %%
amount: int
amount = None #В переменную передан None, а должено быть целое число

# %%
price: Optianal[int]
price = None #Вот теперь мы учли случай, когда не только int, но и None
